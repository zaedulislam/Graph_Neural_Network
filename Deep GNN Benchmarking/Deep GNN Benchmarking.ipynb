# %% [markdown]
# <a href="https://colab.research.google.com/github/zaedulislam/Graph_Neural_Network/blob/main/Deep%20GNN%20Benchmarking/Deep%20GNN%20Benchmarking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cloning the Repository

# %%
# !git clone https://github.com/VITA-Group/Deep_GCN_Benchmarking.git
# Out:
# Cloning into 'Deep_GCN_Benchmarking'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (132/132), done.
# remote: Total 185 (delta 81), reused 133 (delta 49), pack-reused 0
# Receiving objects: 100% (185/185), 788.63 KiB | 7.23 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %% [markdown]
# ### Install and import Conada

# %%
# !pip install -q condacolab

import condacolab
condacolab.install_anaconda()
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:50
# 🔁 Restarting kernel...

# %% [markdown]
# ### Creating the environment

# %%
# !conda create -n deep_gcn_benchmark
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/deep_gcn_benchmark
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate deep_gcn_benchmark
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# ### Installation of Required Packages

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate deep_gcn_benchmark
# pip install -r /content/Deep_GCN_Benchmarking/requirement.txt
#
# pip install torch==1.9.1+cu111 torchvision==0.10.1+cu111 torchaudio===0.9.1 -f https://download.pytorch.org/whl/torch_stable.html
# pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu111.html
# pip install torch-geometric
# pip install torch-cluster==1.5.9
# pip install torch-spline-conv==1.2.1
# Out:
# ...
#   Using cached alembic-1.5.7-py2.py3-none-any.whl (159 kB)
# ...
#   Using cached ase-3.21.1-py3-none-any.whl (2.2 MB)
# ...
#   Using cached attrs-20.3.0-py2.py3-none-any.whl (49 kB)
# ...
#   Using cached blessings-1.7-py3-none-any.whl (18 kB)
# ...
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# ...
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached cliff-3.7.0-py3-none-any.whl (80 kB)
# ...
#   Using cached cmaes-0.8.2-py3-none-any.whl (15 kB)
# ...
#   Using cached cmd2-1.5.0-py3-none-any.whl (133 kB)
# ...
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached colorlog-4.7.2-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# ...
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# ...
#   Using cached googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# ...
#   Using cached gpustat-0.6.0.tar.gz (78 kB)
# ...

# %% [markdown]
# ### Train with Baseline Configurations (Model: GCN, Dataset: Cora)

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate deep_gcn_benchmark
#
# # To solve the error: ModuleNotFoundError: No module named 'ogb'
# pip install ogb
#
# # To solve the error: ModuleNotFoundError: No module named 'texttable'
# pip install texttable
#
# pip install tricks
#
# python /content/Deep_GCN_Benchmarking/main.py --compare_model=1 --cuda_num=0 --type_model=GCN --dataset=Cora
# # <model>   in  [APPNP, DAGNN, GAT, GCN, GCNII, GPRGNN, JKNet, SGC]
# # <dataset> in  [Cora, Citeseer, Pubmed, ogbn-arixv, CoauthorCS, CoauthorPhysics, AmazonComputers, AmazonPhoto, TEXAS, WISCONSIN, CORNELL, ACTOR]
# Out:
# ...
# /content/Deep_GCN_Benchmarking/utils.py:49: UserWarning: configs of GCN not found, use the default setting instead
#   warn(f'configs of {model} not found, use the default setting instead')
# /content/Deep_GCN_Benchmarking/utils.py:56: UserWarning: GCN have no specific settings on Cora. Use the default setting instead.
#   warn(f'{model} have no specific settings on {dataset}. Use the default setting instead.')
# +-------------------+---------------------+
# | Parameter         | Value               |
# +-------------------+---------------------+
# | N_exp             | 100                 |
# +-------------------+---------------------+
# | activation        | relu                |
# +-------------------+---------------------+
# | adj_dropout       | 0.500               |
# +-------------------+---------------------+
# | alpha             | 0.100               |
# +-------------------+---------------------+
# | compare_model     | 1                   |
# ...

# %% [markdown]
# ## Explore different trick combinations

# %% [markdown]
# ## Skip Connection

# %% [markdown]
# ### Backbone: GCN | Dataset: Cora

# %% [markdown]
# ###### **Test accuracy under different skip connection mechanisms. Experiments are conducted on Cora with 2/16/32 layers GCN. Performance are averaged from 100 independent repetitions, and their standard deviation are presented in Table.**
#
# <table>
# <tr>
#     <th> Settings </th>
#     <th> 2 Layers </th>
#     <th> 16 Layers </th>
#     <th> 32 Layers </th>
#     <th> Run the Folloing Command in the Terminal to Train </th>
# </tr>
# <tr>
#     <td> Residual </td>
#     <td> 0.8239±0.0035 </td>
#     <td> 0.2134±0.0357 </td>
#     <td> 0.2156±0.0404 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=Residual --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> Initial </td>
#     <td> 0.8239±0.0035 </td>
#     <td> <strong>0.2165±0.0342</strong>  </td>
#     <td> 0.2144±0.0420 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=Initial --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> Jumping </td>
#     <td> 0.8239±0.0035 </td>
#     <td> 0.2135±0.0349 </td>
#     <td> 0.2153±0.0370 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=Jumping --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> Dense </td>
#     <td> <strong> 0.8239±0.0034 </strong> </td>
#     <td> 0.2119±0.0342 </td>
#     <td> 0.2131±0.0364 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=Dense --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> None </td>
#     <td> <strong> 0.8239±0.0034 </strong> </td>
#     <td> 0.2109±0.0357 </td>
#     <td> <strong> 0.2239±0.0350 </strong> </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## Graph Normalization

# %% [markdown]
# ### Backbone: GCN | Dataset: Cora

# %% [markdown]
# ###### **Test accuracy under different graph normalizations. Experiments are conducted on Cora with 2/16/32 layers GCN and SGC. Performance are averaged from 100 independent repetitions, and their standard deviation are presented in Table.**
#
# <table>
# <tr>
#     <th> Settings </th>
#     <th> 2 Layers </th>
#     <th> 16 Layers </th>
#     <th> 32 Layers </th>
#     <th> Run the Folloing Command in the Terminal to Train </th>
# </tr>
# <tr>
#     <td> BatchNorm </td>
#     <td> <strong>0.8240±0.0035</strong> </td>
#     <td> 0.2103±0.0419 </td>
#     <td> 0.2166±0.0367 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=BatchNorm --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> PairNorm </td>
#     <td> 0.8239±0.0035 </td>
#     <td> 0.2103±0.0338 </td>
#     <td> 0.2157±0.0388 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=PairNorm --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> NodeNorm </td>
#     <td> 0.8239±0.0034 </td>
#     <td> <strong>0.2158±0.0324</strong> </td>
#     <td> <strong>0.2215±0.0371</strong> </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=NodeNorm --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> MeanNorm </td>
#     <td> 0.8239±0.0035 </td>
#     <td> 0.2109±0.0325 </td>
#     <td> 0.2208±0.0394 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=MeanNorm --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> GroupNorm </td>
#     <td> <strong>0.8240±0.0035</strong> </td>
#     <td> 0.2065±0.0343 </td>
#     <td> 0.2162±0.0400 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=GroupNorm--dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> ComboNorm </td>
#     <td> 0.8239±0.0035 </td>
#     <td> 0.2127±0.0386 </td>
#     <td> 0.2181±0.0379 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --type_trick=ComboNorm --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# <tr>
#     <td> NoNorm </td>
#     <td> 0.8239±0.0035 </td>
#     <td> 0.2148±0.0365 </td>
#     <td> 0.2213±0.0380 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --dataset=Cora --num_layers=2/16/32 </td>
# </tr>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## Random Dropping

# %% [markdown]
# ### Backbone: GCN | Dataset: Cora

# %%
python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --dataset=Cora --num_layers=32

# %% [markdown]
# ###### **Test accuracy under different graph normalizations. Experiments are conducted on Cora with 2/16/32 layers GCN and SGC. Performance are averaged from 100 independent repetitions, and their standard deviation are presented in Table.**
#
# <table>
# <tr>
#     <th> Settings </th>
#     <th> 2 Layers </th>
#     <th> 16 Layers </th>
#     <th> 32 Layers </th>
#     <th> Run the Folloing Command in the Terminal to Train </th>
# </tr>
# <tr>
#     <td> No Dropout </td>
#     <td> <strong>0.8239±0.0036</strong> </td>
#     <td> 0.2092±0.0363 </td>
#     <td> 0.2187±0.0367 </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --dataset=Cora --dropout=0 --num_layers=2/16/32 </td>
# </tr>
# <tr>
#
# </tr>
# <tr>
#
# </tr>
# <tr>
#
# </tr>
# <tr>
#
# </tr>
# <tr>
#
# </tr>
# <tr>
#
# </tr>
# </table>

# %% [markdown]
# ## Combining Individual Tricks into the Best Combo

# %% [markdown]
# ###### **Test accuracy under different the best trick combos. Performance are averaged from 100 independent repetitions, and their standard deviation are presented in Table.**
#
# <table>
# <tr>
#     <th> Backbone </th>
#     <th> Dataset </th>
#     <th> Number of Layers </th>
#     <th> Test Accuracy </th>
#     <th> Tricks Combo </th>
#     <th> Run the Folloing Command in the Terminal to Train </th>
# </tr>
# <tr>
#     <td> SGC </td>
#     <td> Cora </td>
#     <td> 64 </td>
#     <td> 0.2532±0.0189 </td>
#     <td> Initial Connection + Dropout + Label Smoothing </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=SGC --dataset=Cora --type_trick=Initial+LabelSmoothing --num_layers=64 </td>
# </tr>
# <tr>
#     <td> SGC </td>
#     <td> Pubmed </td>
#     <td> 32 </td>
#     <td> 0.6899±0.0020 </td>
#     <td> Jumping Connection + No Dropout </td>
#     <td>  python main.py --compare_model=1 --cuda_num=0 --type_model=SGC --dataset=Pubmed --type_trick=Jumping --dropout=0 --num_layers=32 </td>
# </tr>
# <tr>
#     <td> GCN </td>
#     <td> Citeseer </td>
#     <td> 16 </td>
#     <td> 0.1909±0.0248 </td>
#     <td> Initial Connection + Identity Mapping + LabelSmoothing </td>
#     <td> python main.py --compare_model=1 --cuda_num=0 --type_model=GCN --dataset=Citeseer --type_trick=Initial+IdentityMapping+LabelSmoothing --num_layers=16 </td>
# </tr>
# </table>

# %% [markdown]
# ---
